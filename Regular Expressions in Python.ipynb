# %% [markdown]
# # Regular Expressions in Python.

# %% [markdown]
# #### Regular expressions can be used to search for and match specific  text patterns of texts within strings. <br> You can create a regular expression for just about any kind of pattern you can think of.

# %%
# Let's begin by importing the re module, for working with regular expressions in Python.
import re

# %%
# Next we have a text to search....
text_to_search = '''
abcdefghijklmnopqrstuvwxyz
ABCDEFGHIJKLMNOPQRSTUVWXYZ
1234567890

Ha HaHa 

MetaCharacters (Need to be escaped):
. ^ $ * + ? { } [ ] \ | ( )

coreyms.com


321-555-4321
123.555.1234
123*555*1278
800.525.1234
900.545.1234
800.535.1234
900.515.1234

Mr. Schafer
Mr Smith
Ms Davis
Mrs. Robinson
Mr. T

_
cat
mat
pat
bat
'''

sentence = 'Start a sentence and then bring it to an end'

# %%
# let's find say a pattern 'abc'
pattern = re.compile(r'abc')

# %%
matches = pattern.finditer(text_to_search)

# %%
for match in matches:
    print(match.)
# Out:
# <re.Match object; span=(1, 4), match='abc'>

# %%
text_to_search[1:4]
# Out:
# 'abc'

# %%
# the dot(.) is a special character in regular expressions. It actually matches everything.
pattern = re.compile(r'.')
matches = pattern.finditer(text_to_search)
for match in matches:
    print(match)
# Out:
# <re.Match object; span=(1, 2), match='a'>
# <re.Match object; span=(2, 3), match='b'>
# <re.Match object; span=(3, 4), match='c'>
# <re.Match object; span=(4, 5), match='d'>
# <re.Match object; span=(5, 6), match='e'>
# <re.Match object; span=(6, 7), match='f'>
# <re.Match object; span=(7, 8), match='g'>
# <re.Match object; span=(8, 9), match='h'>
# <re.Match object; span=(9, 10), match='i'>
# <re.Match object; span=(10, 11), match='j'>
# <re.Match object; span=(11, 12), match='k'>
# <re.Match object; span=(12, 13), match='l'>
# <re.Match object; span=(13, 14), match='m'>
# <re.Match object; span=(14, 15), match='n'>
# <re.Match object; span=(15, 16), match='o'>
# <re.Match object; span=(16, 17), match='p'>
# <re.Match object; span=(17, 18), match='q'>
# <re.Match object; span=(18, 19), match='r'>
# <re.Match object; span=(19, 20), match='s'>
# <re.Match object; span=(20, 21), match='t'>
# <re.Match object; span=(21, 22), match='u'>
# <re.Match object; span=(22, 23), match='v'>
# ...

# %%
# if we want to actually just search for a period, we have to escape it.
pattern = re.compile(r'\.')
matches = pattern.finditer(text_to_search)
for match in matches:
    print(match)
# Out:
# <re.Match object; span=(114, 115), match='.'>
# <re.Match object; span=(150, 151), match='.'>
# <re.Match object; span=(172, 173), match='.'>
# <re.Match object; span=(176, 177), match='.'>
# <re.Match object; span=(185, 186), match='.'>
# <re.Match object; span=(216, 217), match='.'>
# <re.Match object; span=(229, 230), match='.'>

# %%
# a perhaps practical thing would be to match a url as we would have to escape the period
pattern = re.compile(r'coreyms\.com')
matche = pattern.findall(text_to_search)
print(match)
# Out:
# <re.Match object; span=(167, 178), match='coreyms.com'>

# %%
# now let's actually do some actual pattern matching...
# the \d matches any digit between 0-9
pattern = re.compile(r'\d')
matches = pattern.finditer(text_to_search)
for match in matches:
    print(match)
# Out:
# <re.Match object; span=(55, 56), match='1'>
# <re.Match object; span=(56, 57), match='2'>
# <re.Match object; span=(57, 58), match='3'>
# <re.Match object; span=(58, 59), match='4'>
# <re.Match object; span=(59, 60), match='5'>
# <re.Match object; span=(60, 61), match='6'>
# <re.Match object; span=(61, 62), match='7'>
# <re.Match object; span=(62, 63), match='8'>
# <re.Match object; span=(63, 64), match='9'>
# <re.Match object; span=(64, 65), match='0'>
# <re.Match object; span=(157, 158), match='3'>
# <re.Match object; span=(158, 159), match='2'>
# <re.Match object; span=(159, 160), match='1'>
# <re.Match object; span=(161, 162), match='5'>
# <re.Match object; span=(162, 163), match='5'>
# <re.Match object; span=(163, 164), match='5'>
# <re.Match object; span=(165, 166), match='4'>
# <re.Match object; span=(166, 167), match='3'>
# <re.Match object; span=(167, 168), match='2'>
# <re.Match object; span=(168, 169), match='1'>
# <re.Match object; span=(170, 171), match='1'>
# ...

# %%
# \D matches any charater that is not a digit. Kind of negates \d.
pattern = re.compile(r'\D')
matches = pattern.finditer(text_to_search)
for match in matches:
    print(match)
# Out:
# <re.Match object; span=(0, 1), match='\n'>
# <re.Match object; span=(1, 2), match='a'>
# <re.Match object; span=(2, 3), match='b'>
# <re.Match object; span=(3, 4), match='c'>
# <re.Match object; span=(4, 5), match='d'>
# <re.Match object; span=(5, 6), match='e'>
# <re.Match object; span=(6, 7), match='f'>
# <re.Match object; span=(7, 8), match='g'>
# <re.Match object; span=(8, 9), match='h'>
# <re.Match object; span=(9, 10), match='i'>
# <re.Match object; span=(10, 11), match='j'>
# <re.Match object; span=(11, 12), match='k'>
# <re.Match object; span=(12, 13), match='l'>
# <re.Match object; span=(13, 14), match='m'>
# <re.Match object; span=(14, 15), match='n'>
# <re.Match object; span=(15, 16), match='o'>
# <re.Match object; span=(16, 17), match='p'>
# <re.Match object; span=(17, 18), match='q'>
# <re.Match object; span=(18, 19), match='r'>
# <re.Match object; span=(19, 20), match='s'>
# <re.Match object; span=(20, 21), match='t'>
# <re.Match object; span=(21, 22), match='u'>
# ...

# %%
# \w searches for a word character. A word character is any character in a-z, A-Z, 0-9 and an underscore.
pattern = re.compile(r'\w')
matches = pattern.finditer(text_to_search)
for match in matches:
    print(match)
# Out:
# <re.Match object; span=(1, 2), match='a'>
# <re.Match object; span=(2, 3), match='b'>
# <re.Match object; span=(3, 4), match='c'>
# <re.Match object; span=(4, 5), match='d'>
# <re.Match object; span=(5, 6), match='e'>
# <re.Match object; span=(6, 7), match='f'>
# <re.Match object; span=(7, 8), match='g'>
# <re.Match object; span=(8, 9), match='h'>
# <re.Match object; span=(9, 10), match='i'>
# <re.Match object; span=(10, 11), match='j'>
# <re.Match object; span=(11, 12), match='k'>
# <re.Match object; span=(12, 13), match='l'>
# <re.Match object; span=(13, 14), match='m'>
# <re.Match object; span=(14, 15), match='n'>
# <re.Match object; span=(15, 16), match='o'>
# <re.Match object; span=(16, 17), match='p'>
# <re.Match object; span=(17, 18), match='q'>
# <re.Match object; span=(18, 19), match='r'>
# <re.Match object; span=(19, 20), match='s'>
# <re.Match object; span=(20, 21), match='t'>
# <re.Match object; span=(21, 22), match='u'>
# <re.Match object; span=(22, 23), match='v'>
# ...

# %%
# \W as you would probably guess searches for anything that is not a word character.
pattern = re.compile(r'\W')
matches = pattern.finditer(text_to_search)
for match in matches:
    print(match)
# Out:
# <re.Match object; span=(0, 1), match='\n'>
# <re.Match object; span=(27, 28), match='\n'>
# <re.Match object; span=(54, 55), match='\n'>
# <re.Match object; span=(65, 66), match='\n'>
# <re.Match object; span=(66, 67), match='\n'>
# <re.Match object; span=(69, 70), match=' '>
# <re.Match object; span=(74, 75), match=' '>
# <re.Match object; span=(75, 76), match='\n'>
# <re.Match object; span=(76, 77), match='\n'>
# <re.Match object; span=(91, 92), match=' '>
# <re.Match object; span=(92, 93), match='('>
# <re.Match object; span=(97, 98), match=' '>
# <re.Match object; span=(100, 101), match=' '>
# <re.Match object; span=(103, 104), match=' '>
# <re.Match object; span=(111, 112), match=')'>
# <re.Match object; span=(112, 113), match=':'>
# <re.Match object; span=(113, 114), match='\n'>
# <re.Match object; span=(114, 115), match='.'>
# <re.Match object; span=(115, 116), match=' '>
# <re.Match object; span=(116, 117), match='^'>
# <re.Match object; span=(117, 118), match=' '>
# ...

# %%
# \s matches any whitespaces: that means a space, a tab or a newline
pattern = re.compile(r'\s')
matches = pattern.finditer(text_to_search)
for match in matches:
    print(match)
# Out:
# <re.Match object; span=(0, 1), match='\n'>
# <re.Match object; span=(27, 28), match='\n'>
# <re.Match object; span=(54, 55), match='\n'>
# <re.Match object; span=(65, 66), match='\n'>
# <re.Match object; span=(66, 67), match=' '>
# <re.Match object; span=(67, 68), match=' '>
# <re.Match object; span=(68, 69), match=' '>
# <re.Match object; span=(69, 70), match=' '>
# <re.Match object; span=(70, 71), match=' '>
# <re.Match object; span=(71, 72), match=' '>
# <re.Match object; span=(72, 73), match=' '>
# <re.Match object; span=(73, 74), match=' '>
# <re.Match object; span=(74, 75), match=' '>
# <re.Match object; span=(75, 76), match=' '>
# <re.Match object; span=(76, 77), match=' '>
# <re.Match object; span=(77, 78), match=' '>
# <re.Match object; span=(78, 79), match=' '>
# <re.Match object; span=(79, 80), match=' '>
# <re.Match object; span=(80, 81), match=' '>
# <re.Match object; span=(81, 82), match=' '>
# <re.Match object; span=(85, 86), match='\n'>
# ...

# %%
# \S matches any pattern that is not a whitespace, basically opposite of the above.
pattern = re.compile(r'\S')
matches = pattern.finditer(text_to_search)
for match in matches:
    print(match)
# Out:
# <re.Match object; span=(1, 2), match='a'>
# <re.Match object; span=(2, 3), match='b'>
# <re.Match object; span=(3, 4), match='c'>
# <re.Match object; span=(4, 5), match='d'>
# <re.Match object; span=(5, 6), match='e'>
# <re.Match object; span=(6, 7), match='f'>
# <re.Match object; span=(7, 8), match='g'>
# <re.Match object; span=(8, 9), match='h'>
# <re.Match object; span=(9, 10), match='i'>
# <re.Match object; span=(10, 11), match='j'>
# <re.Match object; span=(11, 12), match='k'>
# <re.Match object; span=(12, 13), match='l'>
# <re.Match object; span=(13, 14), match='m'>
# <re.Match object; span=(14, 15), match='n'>
# <re.Match object; span=(15, 16), match='o'>
# <re.Match object; span=(16, 17), match='p'>
# <re.Match object; span=(17, 18), match='q'>
# <re.Match object; span=(18, 19), match='r'>
# <re.Match object; span=(19, 20), match='s'>
# <re.Match object; span=(20, 21), match='t'>
# <re.Match object; span=(21, 22), match='u'>
# <re.Match object; span=(22, 23), match='v'>
# ...

# %% [markdown]
# #### Now a look at anchors and what they are....

# %%
# Anchors do not actually match any characters but rather envisible positions before or after characters.
# We can use anchors in conjuction with other patterns we are searching for.
# First we have \b which is a word boundary. Word boundaries are indicated by a whitespace or a non-alnum character.
# Say we want to match all the 'ha's that have a word boundary directly before.
# The result matchesthe first one because the start of a new line is a word boundary; and the second because the space
# before it is also a word boundary.
# It's not match the last one in 'HaHa' because there is no word boundary before it.
pattern = re.compile(r'\bHa')
matches = pattern.finditer(text_to_search)
for match in matches:
    print(match)
# Out:
# <re.Match object; span=(67, 69), match='Ha'>
# <re.Match object; span=(70, 72), match='Ha'>

# %%
# Now,if we replace the search pattern with \B, we should match that last 'Ha'. 
# \B indicates not a word boundary.
pattern = re.compile(r'\BHa')
matches = pattern.finditer(text_to_search)
for match in matches:
    print(match)
# Out:
# <re.Match object; span=(72, 74), match='Ha'>

# %%
# ^ will match a position that is the beginning of a string.
# $ will match a position that is the end of a string.
pattern = re.compile(r'^Start')
matches = pattern.finditer(sentence)
for match in matches:
    print(match)
# Out:
# <re.Match object; span=(0, 5), match='Start'>

# %%
pattern = re.compile(r'end$')
matches = pattern.finditer(sentence)
for match in matches:
    print(match)
# Out:
# <re.Match object; span=(41, 44), match='end'>

# %%
# Say we wanted to match the phone numbers 
pattern = re.compile(r'\d{3}\.\d{3}\.\d{4}')
matches = pattern.finditer(text_to_search)
for match in matches:
    print(match)
# Out:
# <re.Match object; span=(170, 182), match='123.555.1234'>

# %%
pattern = re.compile(r'\d{3}-\d{3}-\d{4}')
matches = pattern.finditer(text_to_search)
for match in matches:
    print(match)
# Out:
# <re.Match object; span=(157, 169), match='321-555-4321'>

# %%
# We can match both of them at once like this...
pattern = re.compile(r'\d{3}.\d{3}.\d{4}')
matches = pattern.finditer(text_to_search)
for match in matches:
    print(match)
# Out:
# <re.Match object; span=(157, 169), match='321-555-4321'>
# <re.Match object; span=(170, 182), match='123.555.1234'>

# %% [markdown]
# ### Regular expressions with files

# %%
# let's now read in the data.txt file and try to match some patterns, like the urls and phone numbers.
with open('data.txt', 'r') as file:
    contents = file.read()
    
    pattern = re.compile(r'\d{3}-\d{3}-\d{4}')
    
    matches = pattern.finditer(contents)
    
    for match in matches:
        print(match)
# Out:
# <re.Match object; span=(12, 24), match='615-555-7164'>
# <re.Match object; span=(102, 114), match='800-555-5669'>
# <re.Match object; span=(191, 203), match='560-555-5153'>
# <re.Match object; span=(281, 293), match='900-555-9340'>
# <re.Match object; span=(378, 390), match='714-555-7405'>
# <re.Match object; span=(467, 479), match='800-555-6771'>
# <re.Match object; span=(557, 569), match='783-555-4799'>
# <re.Match object; span=(647, 659), match='516-555-4615'>
# <re.Match object; span=(740, 752), match='127-555-1867'>
# <re.Match object; span=(831, 843), match='608-555-4938'>
# <re.Match object; span=(917, 929), match='568-555-6051'>
# <re.Match object; span=(1005, 1017), match='292-555-1875'>
# <re.Match object; span=(1093, 1105), match='900-555-3205'>
# <re.Match object; span=(1182, 1194), match='614-555-1166'>
# <re.Match object; span=(1273, 1285), match='530-555-2676'>
# <re.Match object; span=(1359, 1371), match='470-555-2750'>
# ...

# %%
## Using character sets
# The search pattern below will return all the phone numbers regardless of the separators between the numbers
pattern = re.compile(r'\d{3}.\d{3}.\d{4}')
matches = pattern.finditer(text_to_search)
for match in matches:
    print(match)
# Out:
# <re.Match object; span=(157, 169), match='321-555-4321'>
# <re.Match object; span=(170, 182), match='123.555.1234'>
# <re.Match object; span=(183, 195), match='123*555*1278'>

# %%
# but what if we wanted to return only the numbers where the separator is either an _ or a .
# that is where using a character set comes in...
# you just need to put the characters you need to match inside of square brackets as below! Observe that you wouldn't
# need to escape the dot within a charactser set.
pattern = re.compile(r'\d{3}[.-]\d{3}[.-]\d{4}')
matches = pattern.finditer(text_to_search)
for match in matches:
    print(match)
# Out:
# <re.Match object; span=(157, 169), match='321-555-4321'>
# <re.Match object; span=(170, 182), match='123.555.1234'>
# <re.Match object; span=(196, 208), match='800.525.1234'>
# <re.Match object; span=(209, 221), match='900.545.1234'>
# <re.Match object; span=(222, 234), match='800.535.1234'>
# <re.Match object; span=(235, 247), match='900.515.1234'>

# %%
# what if we wanted to match just the numbers starting with either 900 or 800?
pattern = re.compile(r'[89]00[.-]\d{3}[.-]\d{4}')
matches = pattern.finditer(text_to_search)
for match in matches:
    print(match)
# Out:
# <re.Match object; span=(196, 208), match='800.525.1234'>
# <re.Match object; span=(209, 221), match='900.545.1234'>
# <re.Match object; span=(222, 234), match='800.535.1234'>
# <re.Match object; span=(235, 247), match='900.515.1234'>

# %%
# let's find the numbers starting with 800 through 999 in the text file.
with open('data.txt', 'r') as file:
    contents = file.read()
    
    pattern = re.compile(r'[98]\d{2}-\d{3}-\d{4}')
    
    matches = pattern.finditer(contents)
    
    for match in matches:
        print(match)
# Out:
# <re.Match object; span=(102, 114), match='800-555-5669'>
# <re.Match object; span=(281, 293), match='900-555-9340'>
# <re.Match object; span=(467, 479), match='800-555-6771'>
# <re.Match object; span=(1093, 1105), match='900-555-3205'>
# <re.Match object; span=(1443, 1455), match='800-555-6089'>
# <re.Match object; span=(1530, 1542), match='880-555-8319'>
# <re.Match object; span=(1701, 1713), match='998-555-7385'>
# <re.Match object; span=(1794, 1806), match='800-555-7100'>
# <re.Match object; span=(1878, 1890), match='903-555-8277'>
# <re.Match object; span=(2055, 2067), match='900-555-5118'>
# <re.Match object; span=(2139, 2151), match='905-555-1630'>
# <re.Match object; span=(2304, 2316), match='884-555-8444'>
# <re.Match object; span=(2391, 2403), match='904-555-8559'>
# <re.Match object; span=(2479, 2491), match='889-555-7393'>
# <re.Match object; span=(2830, 2842), match='900-555-5428'>
# <re.Match object; span=(3109, 3121), match='932-555-7724'>
# ...

# %%
# the dash when placed between characters, it can specify a range value.
pattern = re.compile(r'[1-5]')                # all matches will be digits between 1 and 5
matches = pattern.finditer(text_to_search)
for match in matches:
    print(match)
# Out:
# <re.Match object; span=(55, 56), match='1'>
# <re.Match object; span=(56, 57), match='2'>
# <re.Match object; span=(57, 58), match='3'>
# <re.Match object; span=(58, 59), match='4'>
# <re.Match object; span=(59, 60), match='5'>
# <re.Match object; span=(157, 158), match='3'>
# <re.Match object; span=(158, 159), match='2'>
# <re.Match object; span=(159, 160), match='1'>
# <re.Match object; span=(161, 162), match='5'>
# <re.Match object; span=(162, 163), match='5'>
# <re.Match object; span=(163, 164), match='5'>
# <re.Match object; span=(165, 166), match='4'>
# <re.Match object; span=(166, 167), match='3'>
# <re.Match object; span=(167, 168), match='2'>
# <re.Match object; span=(168, 169), match='1'>
# <re.Match object; span=(170, 171), match='1'>
# <re.Match object; span=(171, 172), match='2'>
# <re.Match object; span=(172, 173), match='3'>
# <re.Match object; span=(174, 175), match='5'>
# <re.Match object; span=(175, 176), match='5'>
# <re.Match object; span=(176, 177), match='5'>
# ...

# %%
# we can do this for letters as well.
pattern = re.compile(r'[a-f]')
matches = pattern.finditer(text_to_search)
for match in matches:
    print(match)
# Out:
# <re.Match object; span=(1, 2), match='a'>
# <re.Match object; span=(2, 3), match='b'>
# <re.Match object; span=(3, 4), match='c'>
# <re.Match object; span=(4, 5), match='d'>
# <re.Match object; span=(5, 6), match='e'>
# <re.Match object; span=(6, 7), match='f'>
# <re.Match object; span=(68, 69), match='a'>
# <re.Match object; span=(71, 72), match='a'>
# <re.Match object; span=(73, 74), match='a'>
# <re.Match object; span=(78, 79), match='e'>
# <re.Match object; span=(80, 81), match='a'>
# <re.Match object; span=(83, 84), match='a'>
# <re.Match object; span=(85, 86), match='a'>
# <re.Match object; span=(86, 87), match='c'>
# <re.Match object; span=(88, 89), match='e'>
# <re.Match object; span=(94, 95), match='e'>
# <re.Match object; span=(95, 96), match='e'>
# <re.Match object; span=(96, 97), match='d'>
# <re.Match object; span=(101, 102), match='b'>
# <re.Match object; span=(102, 103), match='e'>
# <re.Match object; span=(104, 105), match='e'>
# ...

# %%
# We can actually put these ranges back to back and search multiple ranges.
pattern = re.compile(r'[a-fA-F5-8]')
matches = pattern.finditer(text_to_search)
for match in matches:
    print(match)
# Out:
# <re.Match object; span=(1, 2), match='a'>
# <re.Match object; span=(2, 3), match='b'>
# <re.Match object; span=(3, 4), match='c'>
# <re.Match object; span=(4, 5), match='d'>
# <re.Match object; span=(5, 6), match='e'>
# <re.Match object; span=(6, 7), match='f'>
# <re.Match object; span=(28, 29), match='A'>
# <re.Match object; span=(29, 30), match='B'>
# <re.Match object; span=(30, 31), match='C'>
# <re.Match object; span=(31, 32), match='D'>
# <re.Match object; span=(32, 33), match='E'>
# <re.Match object; span=(33, 34), match='F'>
# <re.Match object; span=(59, 60), match='5'>
# <re.Match object; span=(60, 61), match='6'>
# <re.Match object; span=(61, 62), match='7'>
# <re.Match object; span=(62, 63), match='8'>
# <re.Match object; span=(68, 69), match='a'>
# <re.Match object; span=(71, 72), match='a'>
# <re.Match object; span=(73, 74), match='a'>
# <re.Match object; span=(78, 79), match='e'>
# <re.Match object; span=(80, 81), match='a'>
# <re.Match object; span=(81, 82), match='C'>
# ...

# %%
# Within a character set, the ^ negates the search pattern. 
pattern = re.compile(r'[^a-fA-F5-8]')
matches = pattern.finditer(text_to_search)
for match in matches:
    print(match)
# Out:
# <re.Match object; span=(0, 1), match='\n'>
# <re.Match object; span=(7, 8), match='g'>
# <re.Match object; span=(8, 9), match='h'>
# <re.Match object; span=(9, 10), match='i'>
# <re.Match object; span=(10, 11), match='j'>
# <re.Match object; span=(11, 12), match='k'>
# <re.Match object; span=(12, 13), match='l'>
# <re.Match object; span=(13, 14), match='m'>
# <re.Match object; span=(14, 15), match='n'>
# <re.Match object; span=(15, 16), match='o'>
# <re.Match object; span=(16, 17), match='p'>
# <re.Match object; span=(17, 18), match='q'>
# <re.Match object; span=(18, 19), match='r'>
# <re.Match object; span=(19, 20), match='s'>
# <re.Match object; span=(20, 21), match='t'>
# <re.Match object; span=(21, 22), match='u'>
# <re.Match object; span=(22, 23), match='v'>
# <re.Match object; span=(23, 24), match='w'>
# <re.Match object; span=(24, 25), match='x'>
# <re.Match object; span=(25, 26), match='y'>
# <re.Match object; span=(26, 27), match='z'>
# ...

# %%
# if we wanted to match the words cat, mat, pat but not bat; ie all words ending in 'at' but for bat...
pattern = re.compile(r'[cmp]at')
matches = pattern.finditer(text_to_search)
for match in matches:
    print(match)
# Out:
# <re.Match object; span=(301, 304), match='cat'>
# <re.Match object; span=(305, 308), match='mat'>
# <re.Match object; span=(309, 312), match='pat'>

# %%
# now that we know the negation power of the ^, let's be a litle smarter....
pattern = re.compile(r'[^b]at')
matches = pattern.finditer(text_to_search)
for match in matches:
    print(match)
# Out:
# <re.Match object; span=(301, 304), match='cat'>
# <re.Match object; span=(305, 308), match='mat'>
# <re.Match object; span=(309, 312), match='pat'>

# %% [markdown]
# ### Quantifiers in regular expressions...

# %%
# * will match 0 or more specified characters
# + will match 1 or more specified characters
# ? will match 0 or one  specified characters
# {4} will match an exact number of specified characters
# {3,4} will match a range of numbers, (minimum, maximum)

pattern = re.compile(r'M(r|s|rs)\.?\s[A-Z]\w*')
matches = pattern.finditer(text_to_search)
for match in matches:
    print(match)
# Out:
# <re.Match object; span=(249, 260), match='Mr. Schafer'>
# <re.Match object; span=(261, 269), match='Mr Smith'>
# <re.Match object; span=(270, 278), match='Ms Davis'>
# <re.Match object; span=(279, 292), match='Mrs. Robinson'>
# <re.Match object; span=(293, 298), match='Mr. T'>

# %%
emails = '''
CoreyMSchafer@gmail.com
corey.schafer@university.edu
corey-321-schafer@my-work.net
'''
pattern = re.compile(r'[a-zA-Z0-9.-]+@[a-zA-Z-]+\.[a-zA-Z]+')
matches = pattern.finditer(emails)
for match in matches:
    print(match)
# Out:
# <re.Match object; span=(1, 24), match='CoreyMSchafer@gmail.com'>
# <re.Match object; span=(25, 53), match='corey.schafer@university.edu'>
# <re.Match object; span=(54, 83), match='corey-321-schafer@my-work.net'>

# %% [markdown]
# ### Using Groups

# %%
urls = '''
https://www.google.com
http://coreyms.com
htpps://youtube.com
https://www.nasa.gov
'''
pattern = re.compile(r'[a-z]+://(www\.)?(\w+)(\.[a-z]+)')
matches = pattern.finditer(urls)

for match in matches:
    print(match.group(0))
# Out:
# https://www.google.com
# http://coreyms.com
# htpps://youtube.com
# https://www.nasa.gov

# %%
pattern = re.compile(r'[a-z]+://(www\.)?(\w+)(\.[a-z]+)')
matches = pattern.finditer(urls)

for match in matches:
    print(match.group(1))
# Out:
# www.
# None
# None
# www.

# %%
pattern = re.compile(r'[a-z]+://(www\.)?(\w+)(\.[a-z]+)')
matches = pattern.finditer(urls)

for match in matches:
    print(match.group(2))
# Out:
# google
# coreyms
# youtube
# nasa

# %%
pattern = re.compile(r'[a-z]+://(www\.)?(\w+)(\.[a-z]+)')
matches = pattern.finditer(urls)

for match in matches:
    print(match.group(3))
# Out:
# .com
# .com
# .com
# .gov

# %%
pattern = re.compile(r'[a-z]+://(www\.)?(\w+)(\.[a-z]+)')
subbed_urls = pattern.sub(r'\2\3', urls)
print(subbed_urls)
# Out:
# google.com
# coreyms.com
# youtube.com
# nasa.gov

# %% [markdown]
# ### Other methods

# %%
emails = '''
CoreyMSchafer@gmail.com
corey.schafer@university.edu
corey-321-schafer@my-work.net
'''
pattern = re.compile(r'[a-zA-Z0-9.-]+@[a-zA-Z-]+\.[a-zA-Z]+')
matches = pattern.findall(emails)
for match in matches:
    print(match)
# Out:
# CoreyMSchafer@gmail.com
# corey.schafer@university.edu
# corey-321-schafer@my-work.net

# %%
# the match method; returns the first match. It only matches things at the beginning of the string.
pattern = re.compile(r'Start')
match = pattern.match(sentence)
print(match)
# Out:
# <re.Match object; span=(0, 5), match='Start'>

# %%
# searches entire string for the pattern and just like match, returns the first occurrence.
pattern = re.compile(r'sentence')
match = pattern.search(sentence)
print(match)
# Out:
# <re.Match object; span=(8, 16), match='sentence'>

# %% [markdown]
# ### Flags

# %%
# say we wanted to match a word regardless of whether it was uppercase, lowercase or a mixture of both...
pattern = re.compile(r'starT', re.IGNORECASE)  # re.I
match = pattern.search(sentence)
print(match)
# Out:
# <re.Match object; span=(0, 5), match='Start'>
